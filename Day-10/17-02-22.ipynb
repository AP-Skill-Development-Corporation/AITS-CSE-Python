# %% [markdown]
# ## Day objective
# - Pandas continution
#    - Loading and working on Datasets
#    - Data cleaning and manipulation

# %% [markdown]
# ## Getting Data

# %%
import pandas as pd

# %%
import numpy as np

# %%
print(dir(pd))
# Out:
# ['BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Float64Index', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int64Index', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt64Index', 'UInt8Dtype', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__getattr__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_config', '_hashtable', '_is_numpy_dev', '_lib', '_libs', '_np_version_under1p17', '_np_version_under1p18', '_testing', '_tslib', '_typing', '_version', 'api', 'array', 'arrays', 'b
# ...

# %% [markdown]
# ## Loading Data

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/nagamounika5/Datasets/master/Global%20Dataset/Market_Fact.csv')

# %%
df1
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
df1.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
df1.shape
# Out:
# (8399, 10)

# %%
df1.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df1.head(3)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59

# %%
df1.tail()
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8394              28  374.63           7.69                 0.59
# 8395              20  -74.03           6.92                 0.37
# 8396              39  -70.85           5.35                 0.40
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
df1.sample()
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 4725  Ord_5300  Prod_6  SHP_7401  Cust_1782  354.13      0.09              19
#
#       Profit  Shipping_Cost  Product_Base_Margin
# 4725    8.79           8.68                 0.37

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Ord_id               8399 non-null   object
#  1   Prod_id              8399 non-null   object
#  2   Ship_id              8399 non-null   object
#  3   Cust_id              8399 non-null   object
#  4   Sales                8399 non-null   float64
#  5   Discount             8399 non-null   float64
#  6   Order_Quantity       8399 non-null   int64
#  7   Profit               8399 non-null   float64
#  8   Shipping_Cost        8399 non-null   float64
#  9   Product_Base_Margin  8336 non-null   float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.3+ KB

# %% [markdown]
# ## Statistics

# %%
df1.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
df1.mean()
# Out:
# Sales                  1775.878179
# Discount                  0.049671
# Order_Quantity           25.571735
# Profit                  181.184424
# Shipping_Cost            12.838557
# Product_Base_Margin       0.512513
# dtype: float64

# %%
df1['Sales']
# Out:
# 0        136.8100
# 1         42.2700
# 2       4701.6900
# 3       2337.8900
# 4       4233.1500
#           ...
# 8394    2841.4395
# 8395     127.1600
# 8396     243.0500
# 8397    3872.8700
# 8398     603.6900
# Name: Sales, Length: 8399, dtype: float64

# %%
df1['Sales'].mean()
# Out:
# 1775.8781788308156

# %%
df1[['Discount','Order_Quantity']].sum()
# Out:
# Discount             417.19
# Order_Quantity    214777.00
# dtype: float64

# %% [markdown]
# ### Combining
# - jion 2 data sets
# - Adding a new row
# - Adding a new column

# %%
dict1={'Games':['carams','Ludo','PubG'],'Score':[9,8.7,9.4]}
d1=pd.DataFrame(dict1)
d1
# Out:
#     Games  Score
# 0  carams    9.0
# 1    Ludo    8.7
# 2    PubG    9.4

# %%
dict2={'Games':['Templrun','candy crush','free fire'],'Score':[9.2,9.6,10]}
d2=pd.DataFrame(dict2)
d2
# Out:
#          Games  Score
# 0     Templrun    9.2
# 1  candy crush    9.6
# 2    free fire   10.0

# %% [markdown]
# **Joining two datasets**
# - pd.concat([dataset1, dataset2])

# %% [markdown]
# pd.concat([d1, d2])

# %% [markdown]
# - Axis=0-->indicates rows
# - Axis=1-->indicates columns

# %%
pd.concat([d1, d2],axis=1)
# Out:
#     Games  Score        Games  Score
# 0  carams    9.0     Templrun    9.2
# 1    Ludo    8.7  candy crush    9.6
# 2    PubG    9.4    free fire   10.0

# %% [markdown]
# **Adding new row**
# - append()

# %%
d1
# Out:
#     Games  Score
# 0  carams    9.0
# 1    Ludo    8.7
# 2    PubG    9.4

# %%
d1.append({'Games':'cricket','Score':10},ignore_index=True)
# Out:
#      Games  Score
# 0   carams    9.0
# 1     Ludo    8.7
# 2     PubG    9.4
# 3  cricket   10.0

# %% [markdown]
# **Adding a new column**

# %%
d1
# Out:
#     Games  Score
# 0  carams    9.0
# 1    Ludo    8.7
# 2    PubG    9.4

# %%
d1['Subscribers']=['1M','100k','1000M']
d1
# Out:
#     Games  Score Subscribers
# 0  carams    9.0          1M
# 1    Ludo    8.7        100k
# 2    PubG    9.4       1000M

# %% [markdown]
# ### Filtering

# %%
df1.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df1['Sales']>35000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# Name: Sales, Length: 8399, dtype: bool

# %%
df1[df1['Sales']>35000]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 1835               8   3852.19          24.49                 0.39
# 2738              13  27220.69          24.49                 0.39
# 3784               7    102.61          24.49                 0.39

# %%
(df1['Sales']>35000) & (df1['Sales']<46000)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# Name: Sales, Length: 8399, dtype: bool

# %%
df1[(df1['Sales']>35000) & (df1['Sales']<46000)]
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 1835               8  3852.19          24.49                 0.39
# 3784               7   102.61          24.49                 0.39

# %%
df1['Prod_id'].value_counts()
# Out:
# Prod_6     1225
# Prod_3      915
# Prod_4      883
# Prod_5      788
# Prod_8      758
# Prod_13     633
# Prod_1      546
# Prod_2      434
# Prod_15     386
# Prod_11     361
# Prod_17     337
# Prod_12     288
# Prod_9      246
# Prod_10     189
# Prod_7      179
# Prod_16     144
# Prod_14      87
# Name: Prod_id, dtype: int64

# %%
len(df1['Prod_id'].value_counts())
# Out:
# 17

# %%
df1['Prod_id']=='Prod_17'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# Name: Prod_id, Length: 8399, dtype: bool

# %%
df1[df1['Prod_id']=='Prod_17']
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.15      0.08
# 33    Ord_5046  Prod_17  SHP_7042  Cust_1710    630.99      0.07
# 74    Ord_5215  Prod_17  SHP_7287  Cust_1749    140.59      0.01
# 84    Ord_5232  Prod_17  SHP_7306  Cust_1758  21366.51      0.00
# 96    Ord_5489  Prod_17  SHP_7671  Cust_1820    754.92      0.00
# ...        ...      ...       ...        ...       ...       ...
# 8249  Ord_3470  Prod_17  SHP_4805  Cust_1203   5615.40      0.07
# 8265  Ord_4648  Prod_17  SHP_6479  Cust_1587    478.27      0.01
# 8316  Ord_2622  Prod_17  SHP_3587  Cust_1016   2360.43      0.10
# 8333  Ord_2077  Prod_17  SHP_2841   Cust_790    887.94      0.02
# 8355  Ord_3592  Prod_17  SHP_4973  Cust_1266    636.50      0.01
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 4                 35   1219.87          26.30                 0.38
# ...

# %% [markdown]
# ### Sorting
# - Ascending
# - Descending
#   - df.sort_values()

# %%
df1.head()
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
# 4  Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.15      0.08              35
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37
# 4  1219.87          26.30                 0.38

# %%
df1.sort_values(by=['Sales'])
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 6700   Ord_704   Prod_7   SHP_964   Cust_242      2.24      0.01
# 4631   Ord_149   Prod_3  SHP_7028  Cust_1712      3.20      0.09
# 817   Ord_4270   Prod_7  SHP_5959  Cust_1450      3.23      0.06
# 52    Ord_4755  Prod_13  SHP_6628  Cust_1579      3.41      0.06
# 384   Ord_2252   Prod_3  SHP_3064   Cust_881      3.42      0.05
# ...        ...      ...       ...        ...       ...       ...
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 6700               1     -1.97           0.70                 0.37
# ...

# %%
df1.sort_values(by=['Sales'],ascending=False)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 2738  Ord_3084  Prod_17  SHP_4279  Cust_1151  89061.05      0.00
# 3784  Ord_2338  Prod_17  SHP_3207   Cust_932  45923.76      0.07
# 1835  Ord_3875  Prod_17  SHP_5370  Cust_1351  41343.21      0.09
# 2349  Ord_2373  Prod_14  SHP_3259   Cust_942  33367.85      0.01
# 4399  Ord_4614  Prod_14  SHP_6423  Cust_1571  29884.60      0.05
# ...        ...      ...       ...        ...       ...       ...
# 384   Ord_2252   Prod_3  SHP_3064   Cust_881      3.42      0.05
# 52    Ord_4755  Prod_13  SHP_6628  Cust_1579      3.41      0.06
# 817   Ord_4270   Prod_7  SHP_5959  Cust_1450      3.23      0.06
# 4631   Ord_149   Prod_3  SHP_7028  Cust_1712      3.20      0.09
# 6700   Ord_704   Prod_7   SHP_964   Cust_242      2.24      0.01
#
#       Order_Quantity    Profit  Shipping_Cost  Product_Base_Margin
# 2738              13  27220.69          24.49                 0.39
# ...

# %% [markdown]
# ## OOP-Python
# - Python is an object oriented programming language.It allows us to Develop applications using objects and classes

# %% [markdown]
# ### Why OOP
# - Python was designed with an object oriented approach,oop offers some advantages
# - Provides clear program structure
# - it makes development and maintenance easier
# - code reusability

# %% [markdown]
# #### Class
# - class is collection of variables and methods
# - syntax
#           ```
#              class ClassName:
#                    list of variables
#                    list of methods

# %% [markdown]
# - Fuction:  it is collection of statements
# - method:  if function is defined inside the class then we will call that is a method
# ### Method
# ```
# - syntax:   def fun_name():
#                  statement1
#                  -
#                  -
#                  statementN
#                             ```

# %%
#Example for class creation
class Hi:
    a=10
    b=20
    def display():
        print("Hi from display method")
print(Hi.a)
print(Hi.b)
# Out:
# 10
# 20

# %%
Hi.display()
# Out:
# Hi from display method

# %% [markdown]
# ### Object
# - An object is also called as an instance of a class and the process of creating this object is called instantiation
# - syntax: obj_name=class_name

# %%
# Example for object creation
class Hi:
    a=10
    b=20
    def display():
        print('Hi i am freom display method')
obj=Hi  # object creation
print(obj.a)
print(obj.b)
obj.display()
# Out:
# 10
# 20
# Hi i am freom display method

# %%
# Example2 for object creation
class Math():
    '''inside this method i am going to defining add() and mul()'''
    def add(num1,num2):
        return num1+num2
    def mul(num1,num2):
        return num1*num2
obj=Math
print(obj.add(12,13))
print(obj.mul(2,4))
# Out:
# 25
# 8

# %% [markdown]
# ### Inheritance in python
# - a class that inherits all the method and properties from another class
# - parent class is also called as base class
# - child class is the class that inherits from another class so child class is also called as derived class
# - syntax:  class ChildClass(parentClass):

# %% [markdown]
# ## Single inheritance

# %%
class ClassA:
    a,b=10,20
    def display():
        print("I am from classA")
class ClassB(ClassA):
    c,d=12,13
    def show():
        print("I am from ClassB")
obj=ClassB
print(obj.b)
obj.show()
obj.display()
# Out:
# 20
# I am from ClassB
# I am from classA

# %% [markdown]
# <img src='https://pythonlobby.com/wp-content/uploads/2020/09/inheritance-in-python-programming.jpg'>

# %% [markdown]
# <img src=''> # for inserting image
